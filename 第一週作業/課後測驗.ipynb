# %%
plot(range( 87 ))

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
plot[randn[ 87 ]]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-17613509fbb0> in <module>()
# ----> 1 plot[randn[ 87 ]]
#
# TypeError: 'builtin_function_or_method' object is not subscriptable

# %%
plot(randn[ 87])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-4f6f8c8cacd8> in <module>()
# ----> 1 plot(randn[ 87])
#
# TypeError: 'builtin_function_or_method' object is not subscriptable

# %%
plot(randn( 87 ))

# %%
北七 = [8,7]

# %%
print(北七)
# Out:
# [8, 7]

# %%
94*北七
# Out:
# [8,
#  7,
#  8,
#  7,
#  8,
#  7,
#  8,
#  7,
#  8,
#  7,
#  8,
#  7,
#  8,
#  7,
#  8,
#  7,
#  8,
#  7,
#  8,
#  7,
#  8,
#  7,
#  8,
#  7,
#  8,
#  7,
#  8,
#  7,
#  8,
#  7,
#  8,
#  7,
#  8,
#  7,
#  8,
#  7,
#  8,
#  7,
#  8,
#  7,
#  8,
#  7,
#  8,
#  7,
#  8,
#  7,
#  8,
#  7,
#  8,
#  7,
#  8,
#  7,
#  8,
#  7,
#  8,
#  7,
#  8,
#  7,
#  8,
#  7,
#  8,
#  7,
#  8,
#  7,
#  8,
#  7,
#  8,
#  7,
#  8,
#  7,
#  8,
#  7,
#  8,
#  7,
#  8,
#  7,
#  8,
#  7,
#  8,
#  7,
#  8,
#  7,
#  8,
#  7,
#  8,
#  7,
#  8,
#  7,
#  8,
#  7,
#  8,
#  7,
#  8,
#  7,
#  8,
#  7,
#  8,
#  7,
#  8,
#  7,
#  8,
#  7,
#  8,
#  7,
#  8,
#  7,
#  8,
#  7,
#  8,
#  7,
#  8,
#  7,
#  8,
#  7,
#  8,
#  7,
#  8,
#  7,
#  8,
#  7,
#  8,
#  7,
#  8,
#  7,
#  8,
#  7,
#  8,
#  7,
#  8,
#  7,
#  8,
#  7,
#  8,
#  7,
#  8,
#  7,
#  8,
#  7,
#  8,
#  7,
#  8,
#  7,
#  8,
#  7,
#  8,
#  7,
#  8,
#  7,
#  8,
#  7,
#  8,
#  7,
#  8,
#  7,
#  8,
#  7,
#  8,
#  7,
#  8,
#  7,
#  8,
#  7,
#  8,
#  7,
#  8,
#  7,
# ...

# %%
我是串列 = [ ]
I_am_list = ('QQ', 'TAT')
我不是串列 = [ 'QQ', 'TAT']
I_am_not_list = [ ]
print(我是串列)
print(I_am_list )
print(我不是串列)
print(I_am_not_list)
# Out:
# []
# ('QQ', 'TAT')
# ['QQ', 'TAT']
# []

# %%
A = [9, 4, 8, 7]
B = [5, 5, 6, 6]
print(A*B)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-16d5c271be38> in <module>()
#       1 A = [9, 4, 8, 7]
#       2 B = [5, 5, 6, 6]
# ----> 3 print(A*B)
#
# TypeError: can't multiply sequence by non-int of type 'list'

# %%
北七= 87
print(北七)
# Out:
# 87

# %%
A = [9, 4, 8, 7]
B = [5, 5, 6, 6]
A+B
# Out:
# [9, 4, 8, 7, 5, 5, 6, 6]
