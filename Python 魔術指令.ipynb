# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
pi
# Out:
# 3.141592653589793

# %%
sin(pi/2
   )
# Out:
# 1.0

# %%
plot([-2,10,3,13,5])

# %%
randn(10)
# Out:
# array([-2.58578427,  0.46264377,  0.44223967, -0.0688058 ,  0.88718049,
#        -0.15037255,  0.07983795,  0.61243471,  2.56655646, -1.82665264])

# %%
plot(randn(100))

# %%
plot([-2,1,2.7,3.3],[3,-5,6,0])
